# %%
# %matplotlib inline

import csv as csv 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
nmr = pd.read_csv("D:/DataScience/INM433/Coursework/NMR_mortality_rate_1996_2016.csv", encoding = "ISO-8859-1")
imr = pd.read_csv("D:/DataScience/INM433/Coursework/IMR_mortality_rate_1996_2016.csv", encoding = "ISO-8859-1")
u5mr = pd.read_csv("D:/DataScience/INM433/Coursework/U5MR_mortality_rate_1996_2016.csv", encoding = "ISO-8859-1")

# %%
nmr_lower = nmr.iloc[::3,:]
nmr_median = nmr.iloc[1::3,:]
nmr_upper = nmr.iloc[2::3,:]

imr_lower = imr.iloc[::3,:]
imr_median = imr.iloc[1::3,:]
imr_upper = imr.iloc[2::3,:]

u5mr_lower =u5mr.iloc[::3,:]
u5mr_median = u5mr.iloc[1::3,:]
u5mr_upper = u5mr.iloc[2::3,:]

# %%
#Drop null row
nmr_lower_country_total = nmr_lower[["ISO Code","Country Name","CountryTotal"]].drop([585])
nmr_median_country_total = nmr_median[["ISO Code","Country Name","CountryTotal"]].drop([586])
nmr_upper_country_total = nmr_upper[["ISO Code","Country Name","CountryTotal"]].drop([587])

imr_lower_country_total = imr_lower[["ISO Code","Country Name","CountryTotal"]].drop([585])
imr_median_country_total = imr_median[["ISO Code","Country Name","CountryTotal"]].drop([586])
imr_upper_country_total = imr_upper[["ISO Code","Country Name","CountryTotal"]].drop([587])

u5mr_lower_country_total = u5mr_lower[["ISO Code","Country Name","CountryTotal"]].drop([585])
u5mr_median_country_total = u5mr_median[["ISO Code","Country Name","CountryTotal"]].drop([586])
u5mr_upper_country_total = u5mr_upper[["ISO Code","Country Name","CountryTotal"]].drop([587])

# %%
nmr_lower_country_total = nmr_lower_country_total.sort_values(['CountryTotal'], ascending=[0])
nmr_lower_country_total_top_10 = nmr_lower_country_total[0:10]
nmr_lower_country_total_bottom_10 = nmr_lower_country_total[-10:]

nmr_median_country_total = nmr_median_country_total.sort_values(['CountryTotal'], ascending=[0])
nmr_median_country_total_top_10 = nmr_median_country_total[0:10]
nmr_median_country_total_bottom_10 = nmr_median_country_total[-10:]

nmr_upper_country_total = nmr_upper_country_total.sort_values(['CountryTotal'], ascending=[0])
nmr_upper_country_total_top_10 = nmr_upper_country_total[0:10]
nmr_upper_country_total_bottom_10 = nmr_upper_country_total[-10:]

imr_lower_country_total = imr_lower_country_total.sort_values(['CountryTotal'], ascending=[0])
imr_lower_country_total_top_10 = imr_lower_country_total[0:10]
imr_lower_country_total_bottom_10 = imr_lower_country_total[-10:]

imr_median_country_total = imr_median_country_total.sort_values(['CountryTotal'], ascending=[0])
imr_median_country_total_top_10 = imr_median_country_total[0:10]
imr_median_country_total_bottom_10 = imr_median_country_total[-10:]

imr_upper_country_total = imr_upper_country_total.sort_values(['CountryTotal'], ascending=[0])
imr_upper_country_total_top_10 = imr_upper_country_total[0:10]
imr_upper_country_total_bottom_10 = imr_upper_country_total[-10:]

u5mr_lower_country_total = u5mr_lower_country_total.sort_values(['CountryTotal'], ascending=[0])
u5mr_lower_country_total_top_10 = u5mr_lower_country_total[0:10]
u5mr_lower_country_total_bottom_10 = u5mr_lower_country_total[-10:]

u5mr_median_country_total = u5mr_median_country_total.sort_values(['CountryTotal'], ascending=[0])
u5mr_median_country_total_top_10 = u5mr_median_country_total[0:10]
u5mr_median_country_total_bottom_10 =u5mr_median_country_total[-10:]

u5mr_upper_country_total = u5mr_upper_country_total.sort_values(['CountryTotal'], ascending=[0])
u5mr_upper_country_total_top_10 = u5mr_upper_country_total[0:10]
u5mr_upper_country_total_bottom_10 = u5mr_upper_country_total[-10:]

# %%
country_lower_top = [nmr_lower_country_total_top_10["Country Name"].tolist(), imr_lower_country_total_top_10["Country Name"].tolist(), u5mr_lower_country_total_top_10["Country Name"].tolist()]
country_union_lower_top = set().union(*country_lower_top)
nmr_country_union_lower_total = nmr_lower_country_total.loc[nmr_lower_country_total["Country Name"].isin(country_union_lower_top)]
imr_country_union_lower_total = imr_lower_country_total.loc[imr_lower_country_total["Country Name"].isin(country_union_lower_top)]
u5mr_country_union_lower_total = u5mr_lower_country_total.loc[u5mr_lower_country_total["Country Name"].isin(country_union_lower_top)]

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x = nmr_country_union_lower_total["Country Name"],
    y = nmr_country_union_lower_total["CountryTotal"],
    name='NMR',
    marker=dict(        
        color='rgb(55, 83, 109)'
    )
)

trace2 = go.Bar(
    x = imr_country_union_lower_total["Country Name"],
    y = imr_country_union_lower_total["CountryTotal"],
    name='IMR',
    marker=dict(
        color='rgb(26, 118, 255)'
    )
)

trace3 = go.Bar(
    x = u5mr_country_union_lower_total["Country Name"],
    y = u5mr_country_union_lower_total["CountryTotal"],
    name='U5MR',
    marker=dict(
        color='rgb(255, 0, 0)'
    )
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/80.embed" height="525px" width="100%"></iframe>

# %%
country_median_top = [nmr_median_country_total_top_10["Country Name"].tolist(), imr_median_country_total_top_10["Country Name"].tolist(), u5mr_median_country_total_top_10["Country Name"].tolist()]
country_union_median_top = set().union(*country_median_top)
nmr_country_union_median_total = nmr_median_country_total.loc[nmr_median_country_total["Country Name"].isin(country_union_median_top)]
imr_country_union_median_total = imr_median_country_total.loc[imr_median_country_total["Country Name"].isin(country_union_median_top)]
u5mr_country_union_median_total = u5mr_median_country_total.loc[u5mr_median_country_total["Country Name"].isin(country_union_median_top)]

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x = nmr_country_union_median_total["Country Name"],
    y = nmr_country_union_median_total["CountryTotal"],
    name='NMR',
    marker=dict(        
        color='rgb(55, 83, 109)'
    )
)

trace2 = go.Bar(
    x = imr_country_union_median_total["Country Name"],
    y = imr_country_union_median_total["CountryTotal"],
    name='IMR',
    marker=dict(
        color='rgb(26, 118, 255)'
    )
)

trace3 = go.Bar(
    x = u5mr_country_union_median_total["Country Name"],
    y = u5mr_country_union_median_total["CountryTotal"],
    name='U5MR',
    marker=dict(
        color='rgb(255, 0, 0)'
    )
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/80.embed" height="525px" width="100%"></iframe>

# %%
country_upper_top = [nmr_upper_country_total_top_10["Country Name"].tolist(), imr_upper_country_total_top_10["Country Name"].tolist(), u5mr_upper_country_total_top_10["Country Name"].tolist()]
country_union_upper_top = set().union(*country_upper_top)
nmr_country_union_upper_total = nmr_upper_country_total.loc[nmr_upper_country_total["Country Name"].isin(country_union_upper_top)]
imr_country_union_upper_total = imr_upper_country_total.loc[imr_upper_country_total["Country Name"].isin(country_union_upper_top)]
u5mr_country_union_upper_total = u5mr_upper_country_total.loc[u5mr_upper_country_total["Country Name"].isin(country_union_upper_top)]

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x = nmr_country_union_upper_total["Country Name"],
    y = nmr_country_union_upper_total["CountryTotal"],
    name='NMR',
    marker=dict(        
        color='rgb(55, 83, 109)'
    )
)

trace2 = go.Bar(
    x = imr_country_union_upper_total["Country Name"],
    y = imr_country_union_upper_total["CountryTotal"],
    name='IMR',
    marker=dict(
        color='rgb(26, 118, 255)'
    )
)

trace3 = go.Bar(
    x = u5mr_country_union_upper_total["Country Name"],
    y = u5mr_country_union_upper_total["CountryTotal"],
    name='U5MR',
    marker=dict(
        color='rgb(255, 0, 0)'
    )
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/80.embed" height="525px" width="100%"></iframe>

# %%
new = pd.merge(nmr_country_union_lower_total, imr_country_union_lower_total, on = "Country Name")
new = pd.merge(new, u5mr_country_union_lower_total, on = "Country Name")
new.columns = ["Country Name", "NMR_total","IMR_total","U5MR_total"]
new["IMRAfter28Days_total"] = new["IMR_total"] - new["NMR_total"]
new["U5MRAfter1Year_total"] = new["U5MR_total"] - new["IMR_total"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-432-9358feb18d92> in <module>()
#       1 new = pd.merge(nmr_country_union_lower_total, imr_country_union_lower_total, on = "Country Name")
#       2 new = pd.merge(new, u5mr_country_union_lower_total, on = "Country Name")
# ----> 3 new.columns = ["Country Name", "NMR_total","IMR_total","U5MR_total"]
#       4 new["IMRAfter28Days_total"] = new["IMR_total"] - new["NMR_total"]
#       5 new["U5MRAfter1Year_total"] = new["U5MR_total"] - new["IMR_total"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3092         try:
#    3093             object.__getattribute__(self, name)
# -> 3094             return object.__setattr__(self, name, value)
#    3095         except AttributeError:
#    3096             pass
#
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x = new["Country Name"],
    y = new["NMR_total"],
    name='NMR',
    marker=dict(        
        color='rgb(55, 83, 109)'
    )
)

trace2 = go.Bar(
    x = new["Country Name"],
    y = new["IMRAfter28Days_total"],
    name='IMRAfter28Days',
    marker=dict(
        color='rgb(26, 118, 255)'
    )
)

trace3 = go.Bar(
    x = new["Country Name"],
    y = new["U5MRAfter1Year_total"],
    name='U5MRAfter1Year',
    marker=dict(
        color='rgb(255, 0, 0)'
    )
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/80.embed" height="525px" width="100%"></iframe>

# %%
#nmr_country_union_median_total.columns = ["ISOCode", "CountryName","NMR_total"]
#imr_country_union_median_total.columns = ["ISOCode", "CountryName","IMR_total"]
#u5mr_country_union_median_total.columns = ["ISOCode", "CountryName","U5MR_total"]
#new_median = pd.merge(nmr_country_union_median_total, imr_country_union_median_total, on = "CountryName")
#new_median = pd.merge(new_median, u5mr_country_union_median_total, on = "CountryName")
#new_median.drop(['ISOCode_x', 'ISOCode_y'], axis = 1)
#new_median["IMRAfter28Days_total"] = new_median["IMR_total"] - new_median["NMR_total"]
#new_median["U5MRAfter1Year_total"] = new_median["U5MR_total"] - new_median["IMR_total"]
new_median = new_median.iloc[0:10,:]

# %%
new_median
# Out:
#   ISOCode_x               CountryName  NMR_total ISOCode_y  IMR_total ISOCode  \
# 0       PAK                  Pakistan     1143.4       PAK     1665.5     PAK
# 1       AFG               Afghanistan     1119.1       AFG     1597.5     AFG
# 2       GNB             Guinea-Bissau     1040.0       GNB     1807.4     GNB
# 3       SSD               South Sudan     1038.1       SSD     1854.0     SSD
# 4       MLI                      Mali      996.7       MLI     1976.3     MLI
# 5       CAF  Central African Republic      996.5       CAF     2205.9     CAF
# 6       SLE              Sierra Leone      930.0       SLE     2534.8     SLE
# 7       CIV             Côte d'Ivoire      922.7       CIV     1817.2     CIV
# 8       SOM                   Somalia      911.0       SOM     2092.0     SOM
# 9       NGA                   Nigeria      903.0       NGA     1971.6     NGA
#
#    U5MR_total  IMRAfter28Days_total  U5MRAfter1Year_total
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x = new_median["CountryName"],
    y = new_median["NMR_total"],
    name='NMR',
    marker=dict(        
        color='rgb(55, 83, 109)'
    )
)

trace2 = go.Bar(
    x = new_median["CountryName"],
    y = new_median["IMRAfter28Days_total"],
    name='IMRAfter28Days',
    marker=dict(
        color='rgb(26, 118, 255)'
    )
)

trace3 = go.Bar(
    x = new_median["CountryName"],
    y = new_median["U5MRAfter1Year_total"],
    name='U5MRAfter1Year',
    marker=dict(
        color='rgb(255, 0, 0)'
    )
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    title = "NMR, IMR After 28 Days, U5MR After 1 Year",
    barmode='group',
    yaxis = dict(
        title = "Cumulative Mortality Rate"
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Fig. 6')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/174.embed" height="525px" width="100%"></iframe>

# %%
nmr_lower_allyears = nmr_lower.iloc[-1:,4:-1]
nmr_median_allyears = nmr_median.iloc[-1:,4:-1]
nmr_upper_allyears = nmr_upper.iloc[-1:,4:-1]

imr_lower_allyears = imr_lower.iloc[-1:,4:-1]
imr_median_allyears = imr_median.iloc[-1:,4:-1]
imr_upper_allyears = imr_upper.iloc[-1:,4:-1]

u5mr_lower_allyears = u5mr_lower.iloc[-1:,4:-1]
u5mr_median_allyears = u5mr_median.iloc[-1:,4:-1]
u5mr_upper_allyears = u5mr_upper.iloc[-1:,4:-1]

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import datetime 
import plotly.tools as tls

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api
tls.set_credentials_file(username='avsuja', api_key='Jmv8ut9t4cfiKyEnBsSI')

years = np.array([datetime.datetime(i, 1, 1) for i in range(1996,2016)])

trace_lower_nmr = go.Scatter(
                x = years,
                y = np.array(nmr_lower_allyears.values.flatten().tolist()) ,
                name = "NMR - Lower",
                fill='tonexty',
                line = dict(color = '#7ec417'),
                opacity = 0.8)

trace_lower_imr = go.Scatter(
                x = years,
                y = np.array(imr_lower_allyears.values.flatten().tolist()) ,
                name = "IMR - Lower",
                fill='tonexty',
                line = dict(color = '#25c417'),
                opacity = 0.8)

trace_lower_u5mr = go.Scatter(
                x = years,
                y = np.array(u5mr_lower_allyears.values.flatten().tolist()) ,
                name = "U5MR - Lower",
                fill='tonexty',
                line = dict(color = '#179bc4'),
                opacity = 0.8)

trace_median_nmr = go.Scatter(
                x = years,
                y = np.array(nmr_median_allyears.values.flatten().tolist()) ,
                name = "NMR - Median",
                fill='tonexty',
                line = dict(color = '#a795db'),
                opacity = 0.8)

trace_median_imr = go.Scatter(
                x = years,
                y = np.array(imr_median_allyears.values.flatten().tolist()) ,
                name = "IMR - Median",
                fill='tonexty',
                line = dict(color = '#4C65FF'),
                opacity = 0.8)

trace_median_u5mr = go.Scatter(
                x = years,
                y = np.array(u5mr_median_allyears.values.flatten().tolist()) ,
                name = "U5MR - Median",
                fill='tonexty',
                line = dict(color = '#0023FF'),
                opacity = 0.8)

trace_upper_nmr = go.Scatter(
                x = years,
                y = np.array(nmr_upper_allyears.values.flatten().tolist()) ,
                name = "NMR - Upper",
                fill='tonexty',
                line = dict(color = '#cd79ce'),
                opacity = 0.8)

trace_upper_imr = go.Scatter(
                x = years,
                y = np.array(imr_upper_allyears.values.flatten().tolist()) ,
                name = "IMR - Upper",
                fill='tonexty',
                line = dict(color = '#962464'),
                opacity = 0.8)

trace_upper_u5mr = go.Scatter(
                x = years,
                y = np.array(u5mr_upper_allyears.values.flatten().tolist()) ,
                name = "U5MR - Upper",
                fill='tonexty',
                line = dict(color = '#890510'),
                opacity = 0.8)

layout = go.Layout(
    title = "NMR, IMR, U5MR trends and overlaps",
    barmode='group',
    yaxis = dict(
        title = "Cumulative Mortality Rate"
    )
)
data = [trace_lower_nmr,trace_lower_imr,trace_lower_u5mr,trace_median_nmr,trace_median_imr,trace_median_u5mr,trace_upper_nmr,trace_upper_imr,trace_upper_u5mr]

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Fig. 7')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/180.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import pandas as pd

data = [ dict(
        type = 'choropleth',
        locations = nmr_median_country_total["ISO Code"], 
        z = nmr_median_country_total["CountryTotal"], 
        text = nmr_median_country_total["Country Name"], 
        colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            #tickprefix = '$',
            title = 'NMR'),
      ) ]

layout = dict(
    title = 'NMR Cloropleth World Map',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 8')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/184.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import pandas as pd

data = [ dict(
        type = 'choropleth',
        locations = imr_median_country_total["ISO Code"], 
        z = imr_median_country_total["CountryTotal"], 
        text = imr_median_country_total["Country Name"], 
        colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            #tickprefix = '$',
            title = 'IMR'),
      ) ]

layout = dict(
    title = 'IMR Cloropleth World Map',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 8b')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/186.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import pandas as pd

data = [ dict(
        type = 'choropleth',
        locations = u5mr_median_country_total["ISO Code"], 
        z = u5mr_median_country_total["CountryTotal"], 
        text = u5mr_median_country_total["Country Name"], 
        colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            #tickprefix = '$',
            title = 'U5MR'),
      ) ]

layout = dict(
    title = 'U5MR Cloropleth World Map',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 8c' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/188.embed" height="525px" width="100%"></iframe>

# %%
gdp = pd.read_csv("D:/DataScience/INM433/Coursework/GDP_1996_2016.csv", encoding = "ISO-8859-1")

# %%
gdp.drop(gdp.index[16], inplace =True)
gdp.drop(gdp.index[19], inplace = True)

# %%
p = gdp.pivot(index='LOCATION', columns='TIME', values='Value')

# %%
p.to_csv("D:/DataScience/INM433/Coursework/GDP_1996_2016_t.csv")

# %%
gdp = pd.read_csv("D:/DataScience/INM433/Coursework/GDP_1996_2016_t.csv", encoding = "ISO-8859-1")

# %%
gdp.fillna(method='ffill', inplace = True)

# %%
gdp.fillna(method='backfill', inplace = True)

# %%
gdp.to_csv("D:/DataScience/INM433/Coursework/GDP_1996_2016_t1.csv")

# %%
gdp = pd.read_csv("D:/DataScience/INM433/Coursework/GDP_1996_2016_t1.csv", encoding = "ISO-8859-1")

# %%
gdp_country_allyears_total = gdp[["LOCATION","CountryTotal"]][:-1]

# %%
gdp_country_allyears_total.columns = ["ISO Code", "GDPTotal"]

# %%
nmr_median_country_total = nmr_median[["ISO Code","Country Name","CountryTotal"]].drop([586])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-389-2c81cd74e9ab> in <module>()
# ----> 1 nmr_median_country_total = nmr_median[["ISO Code","Country Name","CountryTotal"]].drop([586])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
gdp_country_allyears_total_median = pd.merge(gdp_country_allyears_total, nmr_median_country_total, on = "ISO Code")
gdp_country_allyears_total_median.rename(columns={'CountryTotal':'NMRTotal'}, inplace=True)

gdp_country_allyears_total_median = pd.merge(gdp_country_allyears_total_median, imr_median_country_total, on = "ISO Code")
gdp_country_allyears_total_median.rename(columns={'CountryTotal':'IMRTotal'}, inplace=True)

gdp_country_allyears_total_median = pd.merge(gdp_country_allyears_total_median, u5mr_median_country_total, on = "ISO Code")
gdp_country_allyears_total_median.rename(columns={'CountryTotal':'U5MRTotal'}, inplace=True)

# %%
# Create traces
trace0 = go.Scatter(
    x = gdp_country_allyears_total_median["NMRTotal"],
    y = gdp_country_allyears_total_median["GDPTotal"],
    text = gdp_country_allyears_total_median["Country Name"],
    mode = 'markers',
    name = 'NMR',
    marker = dict(
        size = 10,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace1 = go.Scatter(
    x = gdp_country_allyears_total_median["IMRTotal"],
    y = gdp_country_allyears_total_median["GDPTotal"],
    text = gdp_country_allyears_total_median["Country Name"],
    mode = 'markers',
    name = 'IMR',
    marker = dict(
        size = 10,
        color = 'rgba(12, 47, 183, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace2 = go.Scatter(
    x = gdp_country_allyears_total_median["U5MRTotal"],
    y = gdp_country_allyears_total_median["GDPTotal"],
    text = gdp_country_allyears_total_median["Country Name"],
    mode = 'markers',
    name = 'U5MR',
    marker = dict(
        size = 10,
        color = 'rgba(18, 183, 12, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

data = [trace0, trace1, trace2]

layout = dict(
    title = 'GDP vs Cumulative Mortality Rate',
    xaxis = dict(
        title = "Cumulative Mortality Rate"
        ),
    yaxis = dict(
        title = "GDP (US dollars)"
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 9' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/190.embed" height="525px" width="100%"></iframe>

# %%
# Create traces
trace0 = go.Scatter(
    x = (1/gdp_country_allyears_total_median["NMRTotal"]) * 5000,
    y = gdp_country_allyears_total_median["GDPTotal"],
    text = gdp_country_allyears_total_median["Country Name"],
    mode = 'markers',
    name = 'NMR',
    marker = dict(
        size = 10,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace1 = go.Scatter(
    x = (1/gdp_country_allyears_total_median["IMRTotal"]) * 5000,
    y = gdp_country_allyears_total_median["GDPTotal"],
    text = gdp_country_allyears_total_median["Country Name"],
    mode = 'markers',
    name = 'IMR',
    marker = dict(
        size = 10,
        color = 'rgba(12, 47, 183, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace2 = go.Scatter(
    x = (1/gdp_country_allyears_total_median["U5MRTotal"]) * 5000,
    y = gdp_country_allyears_total_median["GDPTotal"],
    text = gdp_country_allyears_total_median["Country Name"],
    mode = 'markers',
    name = 'IMR',
    marker = dict(
        size = 10,
        color = 'rgba(18, 183, 12, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

data = [trace0, trace1, trace2]

layout = dict(
    title = 'GDP vs Inverse Mortality Rate',
    xaxis = dict(
        title = "Inverse Mortality Rate"
        ),
    yaxis = dict(
        title = "GDP (US dollars)"
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 9a' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/192.embed" height="525px" width="100%"></iframe>

# %%
arg_gdp = gdp.iloc[0, 2:-1]
arg_nmr_median = nmr_median.iloc[6, 3:-1]
gdp_sau = gdp[gdp.LOCATION == 'SAU'].iloc[:, 2:-1]
nmr_median.rename(columns={'ISO Code':'ISOCode'}, inplace=True)
nmr_median_sau = nmr_median[nmr_median.ISOCode == "SAU"].iloc[:,3:-1]

arg_imr_median = imr_median.iloc[6, 3:-1]
imr_median.rename(columns={'ISO Code':'ISOCode'}, inplace=True)
imr_median_sau = imr_median[imr_median.ISOCode == "SAU"].iloc[:,3:-1]

arg_u5mr_median = u5mr_median.iloc[6, 3:-1]
u5mr_median.rename(columns={'ISO Code':'ISOCode'}, inplace=True)
u5mr_median_sau = u5mr_median[u5mr_median.ISOCode == "SAU"].iloc[:,3:-1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:2746: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
gdp_lux = gdp[gdp.LOCATION == 'LUX'].iloc[:, 2:-1]
nmr_median_lux = nmr_median[nmr_median.ISOCode == "LUX"].iloc[:,3:-1]
imr_median_lux = imr_median[imr_median.ISOCode == "LUX"].iloc[:,3:-1]
u5mr_median_lux = u5mr_median[u5mr_median.ISOCode == "LUX"].iloc[:,3:-1]

# %%
gdp
# Out:
#     Unnamed: 0   LOCATION           1996           1997           1998  \
# 0          0.0        ARG   23086.613990   24230.282060   25408.782420
# 1          1.0        AUS   23086.613990   24230.282060   25408.782420
# 2          2.0        AUT   24530.463710   25406.332180   26647.476960
# 3          3.0        BEL   22891.447090   23911.396490   24539.017510
# 4          4.0        BGR    5624.823359    5684.690190    6007.172920
# 5          5.0        BRA    5624.823359    5684.690190    6007.172920
# 6          6.0        CAN   23954.649760   25156.150050   26197.932920
# 7          7.0        CHE   30292.116140   31516.913120   32606.709160
# 8          8.0        CHL    8120.264085    8701.554553    9028.311226
# 9          9.0        CHN    2056.268432    2262.083044    2443.967901
# 10        10.0        COL    2056.268432    2262.083044    2443.967901
# 11        11.0        CRI    6171.174616    6441.021725    6800.753868
# ...

# %%
nmr_median_sau.iloc[0,:]
# Out:
# 1996.5    14.8
# 1997.5    14.0
# 1998.5    13.2
# 1999.5    12.5
# 2000.5    11.9
# 2001.5    11.3
# 2002.5    10.9
# 2003.5    10.4
# 2004.5    10.1
# 2005.5     9.8
# 2006.5     9.5
# 2007.5     9.3
# 2008.5     9.0
# 2009.5     8.7
# 2010.5     8.4
# 2011.5     8.2
# 2012.5     7.9
# 2013.5     7.6
# 2014.5     7.3
# 2015.5     7.1
# 2016.5     6.9
# Name: 448, dtype: float64

# %%
gdp_sau.iloc[0,:]
# Out:
# 1996    26719.14589
# 1997    27346.45480
# 1998    27887.94425
# 1999    27532.29335
# 2000    28860.39407
# 2001    28928.43385
# 2002    28600.86238
# 2003    30500.31638
# 2004    33247.95771
# 2005    35765.83645
# 2006    37855.34969
# 2007    40091.73249
# 2008    43147.17070
# 2009    43073.35390
# 2010    44402.88739
# 2011    48399.41165
# 2012    50429.97256
# 2013    51112.50257
# 2014    52561.54316
# 2015    54085.12057
# 2016    54822.87598
# Name: 49, dtype: float64

# %%
years = np.arange(1996,2016)

trace0 = go.Scatter(
    x = nmr_median_sau.iloc[0,:],
    y = gdp_sau.iloc[0,:],
    text = years,
    mode = 'lines+markers',
    name = 'NMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace1 = go.Scatter(
    x = imr_median_sau.iloc[0,:],
    y = gdp_sau.iloc[0,:],
    text = years,
    mode = 'lines+markers',
    name = 'IMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 120, 100, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace2 = go.Scatter(
    x = u5mr_median_sau.iloc[0,:],
    y = gdp_sau.iloc[0,:],
    text = years,
    mode = 'lines+markers',
    name = 'U5MR',
    marker = dict(
        size = 5,
        color = 'rgba(20, 20, 20, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

data = [trace0, trace1, trace2]

layout = dict(
    title = 'Saudi Arabia - GDP vs Mortality Rate',
    xaxis = dict(
        title = "Mortality Rate"
        ),
    yaxis = dict(
        title = "GDP (US dollars)"
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 11a')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/208.embed" height="525px" width="100%"></iframe>

# %%
gdp_ind = gdp[gdp.LOCATION == 'IND'].iloc[:, 2:-1]
nmr_median_ind = nmr_median[nmr_median.ISOCode == "IND"].iloc[:,3:-1]
imr_median_ind = imr_median[imr_median.ISOCode == "IND"].iloc[:,3:-1]
u5mr_median_ind = u5mr_median[u5mr_median.ISOCode == "IND"].iloc[:,3:-1]

# %%
years = np.arange(1996,2016)

trace0 = go.Scatter(
    x = nmr_median_lux.iloc[0,:],
    y = gdp_lux.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'NMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace1 = go.Scatter(
    x = imr_median_lux.iloc[0,:],
    y = gdp_lux.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'IMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 120, 100, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace2 = go.Scatter(
    x = u5mr_median_lux.iloc[0,:],
    y = gdp_lux.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'U5MR',
    marker = dict(
        size = 5,
        color = 'rgba(20, 20, 20, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

data = [trace0, trace1, trace2]

layout = dict(
    title = 'Luxembourg - GDP vs Mortality Rate',
    xaxis = dict(
        title = "Mortality Rate"
        ),
    yaxis = dict(
        title = "GDP (US dollars)"
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 11b')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/196.embed" height="525px" width="100%"></iframe>

# %%
years = np.arange(1996,2016)

trace0 = go.Scatter(
    x = nmr_median_ind.iloc[0,:],
    y = gdp_ind.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'NMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace1 = go.Scatter(
    x = imr_median_ind.iloc[0,:],
    y = gdp_ind.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'IMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 120, 100, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace2 = go.Scatter(
    x = u5mr_median_ind.iloc[0,:],
    y = gdp_ind.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'U5MR',
    marker = dict(
        size = 5,
        color = 'rgba(20, 20, 20, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

data = [trace0, trace1, trace2]

layout = dict(
    title = 'India - GDP vs Mortality Rate',
    xaxis = dict(
        title = "Mortality Rate"
        ),
    yaxis = dict(
        title = "GDP (US dollars)"
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 11c')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/198.embed" height="525px" width="100%"></iframe>

# %%
gdp_usa = gdp[gdp.LOCATION == 'USA'].iloc[:, 2:-1]
nmr_median_usa = nmr_median[nmr_median.ISOCode == "USA"].iloc[:,3:-1]
imr_median_usa = imr_median[imr_median.ISOCode == "USA"].iloc[:,3:-1]
u5mr_median_usa = u5mr_median[u5mr_median.ISOCode == "USA"].iloc[:,3:-1]

# %%
nmr_median_usa
# Out:
#      1996.5  1997.5  1998.5  1999.5  2000.5  2001.5  2002.5  2003.5  2004.5  \
# 559     4.9     4.8     4.8     4.7     4.6     4.6     4.6     4.6     4.6
#
#      2005.5   ...    2007.5  2008.5  2009.5  2010.5  2011.5  2012.5  2013.5  \
# 559     4.5   ...       4.3     4.2     4.2     4.1     4.0     4.0     4.0
#
#      2014.5  2015.5  2016.5
# 559     3.9     3.8     3.7
#
# [1 rows x 21 columns]

# %%
trace0 = go.Scatter(
    x = nmr_median_usa.iloc[0,:],
    y = gdp_usa.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'NMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace1 = go.Scatter(
    x = imr_median_usa.iloc[0,:],
    y = gdp_usa.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'IMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 120, 100, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace2 = go.Scatter(
    x = u5mr_median_usa.iloc[0,:],
    y = gdp_usa.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'U5MR',
    marker = dict(
        size = 5,
        color = 'rgba(20, 20, 20, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

data = [trace0, trace1, trace2]

layout = dict(
    title = 'USA - GDP vs Mortality Rate',
    xaxis = dict(
        title = "Mortality Rate"
        ),
    yaxis = dict(
        title = "GDP (US dollars)"
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 11d')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/200.embed" height="525px" width="100%"></iframe>

# %%
gdp_pol = gdp[gdp.LOCATION == 'POL'].iloc[:, 2:-1]
nmr_median_pol = nmr_median[nmr_median.ISOCode == "POL"].iloc[:,3:-1]
imr_median_pol = imr_median[imr_median.ISOCode == "POL"].iloc[:,3:-1]
u5mr_median_pol = u5mr_median[u5mr_median.ISOCode == "POL"].iloc[:,3:-1]

# %%
trace0 = go.Scatter(
    x = nmr_median_pol.iloc[0,:],
    y = gdp_pol.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'NMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace1 = go.Scatter(
    x = imr_median_pol.iloc[0,:],
    y = gdp_pol.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'IMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 120, 100, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace2 = go.Scatter(
    x = u5mr_median_pol.iloc[0,:],
    y = gdp_pol.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'U5MR',
    marker = dict(
        size = 5,
        color = 'rgba(20, 20, 20, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

data = [trace0, trace1, trace2]

layout = dict(
    title = 'Poland - GDP vs Mortality Rate',
    xaxis = dict(
        title = "Mortality Rate"
        ),
    yaxis = dict(
        title = "GDP (US dollars)"
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 11e')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/202.embed" height="525px" width="100%"></iframe>

# %%
gdp_idn = gdp[gdp.LOCATION == 'IDN'].iloc[:, 2:-1]
nmr_median_idn = nmr_median[nmr_median.ISOCode == "IDN"].iloc[:,3:-1]
imr_median_idn = imr_median[imr_median.ISOCode == "IDN"].iloc[:,3:-1]
u5mr_median_idn = u5mr_median[u5mr_median.ISOCode == "IDN"].iloc[:,3:-1]

# %%
trace0 = go.Scatter(
    x = nmr_median_idn.iloc[0,:],
    y = gdp_idn.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'NMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace1 = go.Scatter(
    x = imr_median_idn.iloc[0,:],
    y = gdp_idn.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'IMR',
    marker = dict(
        size = 5,
        color = 'rgba(152, 120, 100, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

trace2 = go.Scatter(
    x = u5mr_median_idn.iloc[0,:],
    y = gdp_idn.iloc[0,:],
    #text = years,
    mode = 'lines+markers',
    name = 'U5MR',
    marker = dict(
        size = 5,
        color = 'rgba(20, 20, 20, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

data = [trace0, trace1, trace2]

layout = dict(
    title = 'Indonesia - GDP vs Mortality Rate',
    xaxis = dict(
        title = "Mortality Rate"
        ),
    yaxis = dict(
        title = "GDP (US dollars)"
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 11f')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/206.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace0 = go.Scatter(
    x=np.arange(1996,2016),
    y=gdp_sau.iloc[0,:],
    text = nmr_median_sau.iloc[0,:],
    name = 'NMR',
    mode='markers',
    marker=dict(
        size=nmr_median_sau.iloc[0,:],
        color = ['rgb(93, 164, 214)'] * 21
    )
)

trace1 = go.Scatter(
    x=np.arange(1996,2016),
    y=gdp_sau.iloc[0,:],
    text = imr_median_sau.iloc[0,:],
    name = 'IMR',
    mode='markers',
    marker=dict(
        size=imr_median_sau.iloc[0,:],
        color = ['rgb(255, 144, 14)'] * 21
    )
)

trace2 = go.Scatter(
    x=np.arange(1996,2016),
    y=gdp_sau.iloc[0,:],
    text = u5mr_median_sau.iloc[0,:],
    name = 'U5MR',
    mode='markers',
    marker=dict(
        size=u5mr_median_sau.iloc[0,:],
        color = ['rgb(44, 160, 101)'] * 21
    )
)

data = [trace2, trace1, trace0]
py.iplot(data, filename='bubblechart-size')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/98.embed" height="525px" width="100%"></iframe>

# %%
gdp_country_allyears_total_median
# Out:
#    ISO Code      GDPTotal      Country Name_x  NMRTotal      Country Name_y  \
# 0       ARG  4.543286e+05           Argentina     191.9           Argentina
# 1       AUS  7.614151e+05           Australia      64.2           Australia
# 2       AUT  7.855218e+05             Austria      57.9             Austria
# 3       BEL  7.348523e+05             Belgium      56.2             Belgium
# 4       BGR  2.424930e+05            Bulgaria     127.8            Bulgaria
# 5       BRA  2.420482e+05              Brazil     277.4              Brazil
# 6       CAN  7.537550e+05              Canada      78.4              Canada
# 7       CHE  9.684017e+05         Switzerland      68.1         Switzerland
# 8       CHL  3.161376e+05               Chile     116.8               Chile
# 9       CHN  1.558121e+05               China     291.0               China
# 10      COL  1.812316e+05            Colombia     245.4            Colombia
# ...

# %%
import plotly.plotly as py
import pandas as pd

cities = []
scale = 5000
    
city = dict(
    type = 'scattergeo',
    locationmode = "ISO-3",
    lon = gdp_country_allyears_total_median["Longitude"],
    lat = gdp_country_allyears_total_median["Latitude"],
    text = gdp_country_allyears_total_median["Country Name"],
    marker = dict(
        size = gdp_country_allyears_total_median["NMRTotal"]/5,
        color = ['rgb(255,116,217)'] * 52,
        line = dict(width=0.5, color='rgb(40,40,40)'),
        sizemode = 'area'
        ),
    name = 'NMR')
cities.append(city)

layout = dict(
        title = 'World',
        showlegend = True,
        geo = dict(
            scope='world',
            projection=dict( type='Mercator' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            showcountries=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 0, 255)"
        ),
    )

fig = dict( data=cities, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 12' )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Longitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-521-55f7a3d57567> in <module>()
#       8     type = 'scattergeo',
# ...

# %%
#CountryLatLon = pd.read_csv("D:/DataScience/INM433/Coursework/CountryLatLon.csv", encoding = "ISO-8859-1")
#CountryLatLon

gdp_country_allyears_total_median.rename(columns={"ISO Code": "ISOCode"}, inplace = True)

gdp_country_allyears_total_median = pd.merge(gdp_country_allyears_total_median,CountryLatLon,on="ISOCode")
#gdp_country_allyears_total_median.rename(columns={"ISO Code": "ISOCode"}, inplace = True)


#len(gdp_country_allyears_total_median["Country Name"])
#gdp_country_allyears_total_median
# Out:
#    ISOCode      GDPTotal      Country Name_x  NMRTotal      Country Name_y  \
# 0      ARG  4.543286e+05           Argentina     191.9           Argentina
# 1      AUS  7.614151e+05           Australia      64.2           Australia
# 2      AUT  7.855218e+05             Austria      57.9             Austria
# 3      BEL  7.348523e+05             Belgium      56.2             Belgium
# 4      BGR  2.424930e+05            Bulgaria     127.8            Bulgaria
# 5      BRA  2.420482e+05              Brazil     277.4              Brazil
# 6      CAN  7.537550e+05              Canada      78.4              Canada
# 7      CHE  9.684017e+05         Switzerland      68.1         Switzerland
# 8      CHL  3.161376e+05               Chile     116.8               Chile
# 9      CHN  1.558121e+05               China     291.0               China
# 10     COL  1.812316e+05            Colombia     245.4            Colombia
# ...

# %%
import plotly.plotly as py
import pandas as pd

data = [ dict(
        type = 'choropleth',
        locations = gdp_country_allyears_total_median["ISOCode"], 
        z = gdp_country_allyears_total_median["GDPTotal"], 
        text = gdp_country_allyears_total_median["Country Name"], 
        colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            #tickprefix = '$',
            title = 'GDP (US Dollars)'),
      ) ]

layout = dict(
    title = 'GDP Cloropleth World Map',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 12')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/210.embed" height="525px" width="100%"></iframe>

# %%
#classify countries
#regression
#residual analysis

#scipy.stats.pearsonr(x, y)


#gdp

# %%
gdp_arg = gdp[gdp.LOCATION == 'ARG'].iloc[:, 2:-1].values.flatten().tolist()
nmr_arg = nmr_median[nmr_median.ISOCode == "ARG"].iloc[:,3:-1].values.flatten().tolist()
corr,pvalue = scipy.stats.pearsonr(gdp_arg, nmr_arg)
# Out:
# (0.54256492467529838, 0.011046229160278734)

# %%
gdp.drop([16], inplace=True)

# %%
gdp.drop([19], inplace=True)

# %%
gdp.drop([42], inplace=True)

# %%
gdp.drop([43], inplace=True)

# %%
gdp
# Out:
#     Unnamed: 0   LOCATION           1996           1997           1998  \
# 0          0.0        ARG   23086.613990   24230.282060   25408.782420
# 1          1.0        AUS   23086.613990   24230.282060   25408.782420
# 2          2.0        AUT   24530.463710   25406.332180   26647.476960
# 3          3.0        BEL   22891.447090   23911.396490   24539.017510
# 4          4.0        BGR    5624.823359    5684.690190    6007.172920
# 5          5.0        BRA    5624.823359    5684.690190    6007.172920
# 6          6.0        CAN   23954.649760   25156.150050   26197.932920
# 7          7.0        CHE   30292.116140   31516.913120   32606.709160
# 8          8.0        CHL    8120.264085    8701.554553    9028.311226
# 9          9.0        CHN    2056.268432    2262.083044    2443.967901
# 10        10.0        COL    2056.268432    2262.083044    2443.967901
# 11        11.0        CRI    6171.174616    6441.021725    6800.753868
# ...

# %%
gdp1 = gdp.iloc[:-1,:]
gdp1
# Out:
#     Unnamed: 0 LOCATION          1996          1997          1998  \
# 0          0.0      ARG  23086.613990  24230.282060  25408.782420
# 1          1.0      AUS  23086.613990  24230.282060  25408.782420
# 2          2.0      AUT  24530.463710  25406.332180  26647.476960
# 3          3.0      BEL  22891.447090  23911.396490  24539.017510
# 4          4.0      BGR   5624.823359   5684.690190   6007.172920
# 5          5.0      BRA   5624.823359   5684.690190   6007.172920
# 6          6.0      CAN  23954.649760  25156.150050  26197.932920
# 7          7.0      CHE  30292.116140  31516.913120  32606.709160
# 8          8.0      CHL   8120.264085   8701.554553   9028.311226
# 9          9.0      CHN   2056.268432   2262.083044   2443.967901
# 10        10.0      COL   2056.268432   2262.083044   2443.967901
# 11        11.0      CRI   6171.174616   6441.021725   6800.753868
# 12        12.0      CYP  17298.671290  17766.485020  18738.970760
# ...

# %%
import statsmodels.api as sm

Corr = []
#Drop total row


for index,row in gdp1.iterrows():
    gdp_row = row.iloc[2:-1].tolist()
    nmr_row = nmr_median[nmr_median.ISOCode == row.LOCATION].iloc[:,3:-1].values.flatten().tolist()
    corr,pvalue = scipy.stats.pearsonr(nmr_row, gdp_row)
    model = sm.OLS(nmr_row,gdp_row).fit()
    
    #print(row.LOCATION)
    #print(len(gdp_row))
    #print(len(nmr_row))
    
    Corr.append([row.LOCATION, corr, pvalue, model.rsquared])
    
    #print(row.LOCATION,corr,pvalue)
    #print(model.rsquared)

# %%
gdp_row
# Out:
# [7185.836179999999,
#  7353.858473,
#  7332.1751730000005,
#  7488.87704,
#  7849.069625,
#  8117.083781,
#  8425.051093,
#  8733.851545,
#  9260.616681,
#  9929.101725,
#  10658.71203,
#  11368.817009999999,
#  11792.110190000001,
#  11529.35097,
#  11847.01899,
#  12286.4741,
#  12565.46988,
#  12901.91858,
#  13119.69123,
#  13398.60942,
#  13328.9122]

# %%
corr_data = pd.DataFrame(Corr)
corr_data.columns = ["ISOCode", "Correlation", "PValue","RSquared"]
corr_data
# Out:
#    ISOCode  Correlation        PValue  RSquared
# 0      ARG     0.542565  1.104623e-02  0.955086
# 1      AUS    -0.969475  4.672469e-13  0.869080
# 2      AUT    -0.993468  2.231612e-19  0.882563
# 3      BEL    -0.944669  1.205929e-10  0.874158
# 4      BGR    -0.982114  3.059274e-15  0.661996
# 5      BRA    -0.984545  7.706648e-16  0.696547
# 6      CAN    -0.627490  2.326686e-03  0.948229
# 7      CHE    -0.956900  1.178938e-11  0.915551
# 8      CHL    -0.591575  4.732389e-03  0.859777
# 9      CHN    -0.856736  7.131817e-07  0.269418
# 10     COL    -0.984159  9.728567e-16  0.693667
# 11     CRI    -0.909606  1.111875e-08  0.852743
# 12     CYP    -0.937179  3.911392e-10  0.749731
# 13     CZE    -0.896625  3.776443e-08  0.723360
# 14     DEU    -0.956913  1.175861e-11  0.907527
# 15     DNK    -0.780647  2.973796e-05  0.910448
# 16     ESP    -0.977045  3.209296e-14  0.862535
# 17     EST    -0.949923  4.772054e-11  0.396498
# 18     FIN    -0.970791  3.090078e-13  0.800879
# ...

# %%
corr_data[corr_data.correlation] =

# %%
import plotly.plotly as py
import pandas as pd

data = [ dict(
        type = 'choropleth',
        locations = corr_data["ISOCode"], 
        z = corr_data["RSquared"], 
        text = corr_data["ISOCode"], 
        colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            #tickprefix = '$',
            title = 'RSquared'),
      ) ]

layout = dict(
    title = 'RSquared Cloropleth',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 12b' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/214.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import pandas as pd

data = [ dict(
        type = 'choropleth',
        locations = corr_data["ISOCode"], 
        z = corr_data["Correlation"], 
        text = corr_data["ISOCode"], 
        colorscale = [[0,"rgb(5, 10, 172)"],[-0.35,"rgb(40, 60, 190)"],[-0.5,"rgb(70, 100, 245)"],\
            [-0.6,"rgb(90, 120, 245)"],[-0.7,"rgb(106, 137, 247)"],[-1,"rgb(220, 220, 220)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            #tickprefix = '$',
            title = 'Correlation'),
      ) ]

layout = dict(
    title = 'Correlation Cloropleth',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='Fig. 12c' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/230.embed" height="525px" width="100%"></iframe>

# %%
import numpy as np
from sklearn.cluster import KMeans

### For the purposes of this example, we store feature data from our
### dataframe `df`, in the `f1` and `f2` arrays. We combine this into
### a feature matrix `X` before entering it into the algorithm.
f1 = gdp_country_allyears_total_median["NMRTotal"].values
f2 =  gdp_country_allyears_total_median["GDPTotal"].values

plt.scatter(f1,f2, s=50);

X=np.matrix(list(zip(f1,f2)))
            
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
            
y_kmeans = kmeans.predict(X)          

plt.scatter(f1, f2, c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
from sklearn.cluster import KMeans

### For the purposes of this example, we store feature data from our
### dataframe `df`, in the `f1` and `f2` arrays. We combine this into
### a feature matrix `X` before entering it into the algorithm.
f1 = gdp_country_allyears_total_median["IMRTotal"].values
f2 =  gdp_country_allyears_total_median["GDPTotal"].values

plt.scatter(f1,f2, s=50);

X=np.matrix(list(zip(f1,f2)))
            
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
            
y_kmeans = kmeans.predict(X)          

plt.scatter(f1, f2, c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
from sklearn.cluster import KMeans

### For the purposes of this example, we store feature data from our
### dataframe `df`, in the `f1` and `f2` arrays. We combine this into
### a feature matrix `X` before entering it into the algorithm.
f1 = gdp_country_allyears_total_median["U5MRTotal"].values
f2 =  gdp_country_allyears_total_median["GDPTotal"].values

plt.scatter(f1,f2, s=50);

X=np.matrix(list(zip(f1,f2)))
            
kmeans = KMeans(n_clusters=8)
kmeans.fit(X)
            
y_kmeans = kmeans.predict(X)          

plt.scatter(f1, f2, c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
centers
# Out:
# array([[  1.77017857e+02,   3.41604525e+05],
#        [  6.46173913e+01,   7.49219541e+05],
#        [  4.21000000e+01,   1.54452102e+06]])

# %%
centers[:, 0]
# Out:
# array([  63.67916667,  177.01785714])

# %%
#nmr_upper[["ISO Code", "1996.5"]]
#imr_median[["ISOCode", "1996.5","2016.5"]]
#u5mr_upper[["ISO Code", "1996.5"]]
#imr_upper[["ISO Code", "2006.5"]]
#imr_upper[[ "2006.5"]]
nmr_median_1996 = nmr_median[["ISOCode","1996.5", "2016.5"]].iloc[:-1].sort_values(['1996.5'], ascending=[0])
imr_median_1996 = imr_median[["ISOCode", "1996.5","2016.5"]].iloc[:-1].sort_values(['1996.5'], ascending=[0])
u5mr_median_1996 = u5mr_median[["ISOCode", "1996.5","2016.5"]].iloc[:-1].sort_values(['1996.5'], ascending=[0])
#nmr_median_2016 = nmr_median[["ISOCode","2016.5"]].iloc[:-1]

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace0 = go.Scatter(
    x = nmr_median_1996["ISOCode"],
    y = nmr_median_1996["1996.5"],
    mode='lines',
    name = "NMR 1996",
    line=dict(width=1.0,
             color='rgb(255,0,0)') #,
    #fill='tonexty'
)

trace1 = go.Scatter(
    x = nmr_median_1996["ISOCode"],
    y = nmr_median_1996["2016.5"],
    mode='lines',
    name = "NMR 2016",
    line=dict(width=1.0,
              color='rgb(0, 153, 0)') #,
    #fill='tonexty'
)


data = [trace0, trace1]
layout = go.Layout(
    title="NMR 1996 vs 2016",
    showlegend=True,
    xaxis=dict(
        type='category',
    ),
    yaxis=dict(
        type='linear',
        title="NMR Median" #,
        #range=[1, 100],
        #dtick=20,
        #ticksuffix='%'
    )
)


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Fig. 15a')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/220.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace0 = go.Scatter(
    x = imr_median_1996["ISOCode"],
    y = imr_median_1996["1996.5"],
    mode='lines',
    name = "IMR 1996",
    line=dict(width=1.0,
             color='rgb(255,0,0)') #,
    #fill='tonexty'
)

trace1 = go.Scatter(
    x = imr_median_1996["ISOCode"],
    y = imr_median_1996["2016.5"],
    mode='lines',
    name = "IMR 2016",
    line=dict(width=1.0,
              color='rgb(0, 153, 0)') #,
    #fill='tonexty'
)



data = [trace0, trace1]
layout = go.Layout(
    title="IMR 1996 vs 2016",
    showlegend=True,
    xaxis=dict(
        type='category',
    ),
    yaxis=dict(
        type='linear',
        title="NMR Median" #,
        #range=[1, 100],
        #dtick=20,
        #ticksuffix='%'
    )
)


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Fig. 15b')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/222.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace0 = go.Scatter(
    x = u5mr_median_1996["ISOCode"],
    y = u5mr_median_1996["1996.5"],
    mode='lines',
    name = "U5MR 1996",
    line=dict(width=1.0,
             color='rgb(255,0,0)') #,
    #fill='tonexty'
)

trace1 = go.Scatter(
    x = u5mr_median_1996["ISOCode"],
    y = u5mr_median_1996["2016.5"],
    mode='lines',
    name = "U5MR 2016",
    line=dict(width=1.0,
              color='rgb(0, 153, 0)') #,
    #fill='tonexty'
)


data = [trace0, trace1]
layout = go.Layout(
    title="U5MR 1996 vs 2016",
    showlegend=True,
    xaxis=dict(
        type='category',
    ),
    yaxis=dict(
        type='linear',
        title="U5MR Median" #,
        #range=[1, 100],
        #dtick=20,
        #ticksuffix='%'
    )
)


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Fig. 15c')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/226.embed" height="525px" width="100%"></iframe>

# %%
gdp_1996 = gdp1[["LOCATION", "1996","2016"]].iloc[:-1].sort_values(['1996'], ascending=[1])
gdp_1996
# Out:
#    LOCATION          1996          2016
# 9       CHN   2056.268432   23477.54375
# 10      COL   2056.268432   14129.58566
# 4       BGR   5624.823359   19057.77976
# 5       BRA   5624.823359   15243.03915
# 27      IND   5746.409998   27007.63449
# 26      IDN   5746.409998   27007.63449
# 47      ROU   5779.587607   23406.33036
# 36      LVA   5796.768015   25835.60814
# 48      RUS   5935.153042   23224.67664
# 11      CRI   6171.174616   14129.58566
# 34      LTU   6379.741598   29924.19266
# 18      EST   6779.838930   29633.14077
# 37      MEX   7820.477090   18579.42662
# 8       CHL   8120.264085   23477.54375
# 45      POL   8327.321371   27574.63528
# 25      HUN   9341.011951   27007.63449
# 50      SVK   9360.732907   30694.23599
# 53      TUR  10810.854540   24807.22666
# 51      SVN  14263.831930   33424.74062
# 33      KOR  14428.171430   35750.56558
# 38      MLT  14576.272910   37880.53199
# 13      CZE  14584.021200   35127.44029
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace0 = go.Scatter(
    x = gdp_1996["LOCATION"],
    y = gdp_1996["1996"],
    mode='lines',
    name = "GDP 1996",
    line=dict(width=1.0,
             color='rgb(245,22, 230)') #,
    #fill='tonexty'
)

trace1 = go.Scatter(
    x = gdp_1996["LOCATION"],
    y = gdp_1996["2016"],
    mode='lines',
    name = "GDP 2016",
    line=dict(width=1.0,
              color='rgb(13, 42, 185)') #,
    #fill='tonexty'
)


data = [trace0, trace1]
layout = go.Layout(
    title="GDP 1996 vs 2016",
    showlegend=True,
    xaxis=dict(
        type='category',
    ),
    yaxis=dict(
        type='linear',
        title="GDP (US Dollars)" #,
        #range=[1, 100],
        #dtick=20,
        #ticksuffix='%'
    )
)


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Fig. 15d')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~avsuja/228.embed" height="525px" width="100%"></iframe>
